# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# Ans:
#
# *       -> is a operator
# 'hello' -> is a value
# -87.8   -> is a value
# /       -> is a operator
# +       -> is a operator
# 6       -> is a value
#
#
# 2. What is the difference between string and variable?
#
# Ans:
#
# String: String is a data type which stores the some text value. The value may be characters/character or alphabetic or alphanumeric.
# Ex: 'ineuron', 's', 'as12', etc,.
#
# Variable: Variable is a name that stores/refers to some value.
# Ex: a=4, here 'a' stores the value 4
#
#
# 3. Describe three different data types.
#
# Ans:
#
# int :  stores the numeric value
# string : stores the alphanumeric value or alphabetic value or character
# boolean : which stores the True or False
# complex : which stores the value in the form of a+bj, where a and b refers to some numeric value
#
#
# 4. What is an expression made up of? What do all expressions do?
#
# Ans:
#
# Anything that does something is a statement. Any assignment to a variable or function call is a statement. Any value contained in that statement in an expression.
# Expressions do some operations like addition, multiplication, subtraction, etc,.
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Ans:
#
# Expressions represent something, like a number, a string, or an instance of a class. Any value is an expression!
# Anything that does something is a statement. Any assignment to a variable or function call is a statement. Any value contained in that statement in an expression.
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:
#
# 22
#
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:
#
# 'spamspamspam'
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans:
#
# we cannot assign value to the literals variable.
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans:
#
# int()
# float()
# string()
#
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans:
#
# We can only concatenate str to str. we cannot concatenate str and int value. To fix this error we need to convert 99 to str and then try to concatenate.
# 'I have eaten ' + '99' + ' burritos.'
